# %%
import pandas as pd #importing pandas 
#Jud= pd.read_excel('DallasCounty_EvictionJudgements.xlsx')

#Rec = pd.read_excel('DallasCounty_EvictionRecords.xlsx')

#Hist = pd.read_excel('DallasCounty_HistoricalEvictionRecords.xlsx')


#reading in csv and excel files

# %%
Geo['judgment_amt'] = Geo['judgment_amt'].replace(',','', regex=True)
#removing commas
#converting to float:
Geo['judgment_amt']=Geo['judgment_amt'].astype(float)

#only allowing rows greater than 0:
Geo= Geo[(Geo['judgment_amt'] > 0)]

# %%
Geo.head(5)
# Out:
#     Unnamed: 0 case_number   file_date judgment_date.x judgment_signed  \
# 0            1    2100568E   8/11/2021       3/14/2022       3/14/2022
# 3            4    2100818E  10/22/2021       5/16/2022             NaN
# 4            5    2100825E  10/28/2021       3/14/2022       3/14/2022
# 11          12    2100854E   11/8/2021       3/18/2022       3/18/2022
# 19          20    2100925K  10/25/2021       3/10/2022       3/10/2022
#
#     judgment_amt total_paid       court  filed_date              pl_address  \
# 0        4378.00        141  Court  2-2   8/11/2021       11760 FERGUSON RD
# 3        5637.26        221  Court  2-2  10/22/2021   5550 GRANITE PKWY 165
# 4        4789.09        141  Court  2-2  10/28/2021        2605 FRANKLIN DR
# 11       3557.70        141  Court  2-2   11/8/2021        4900 VIA VENTURA
# 19       4058.29        141  Court  1-2  10/25/2021  3415 CUSTER RD STE 122
#
#     ... df_zip judgment_date.y  amount_filed            NAME_2020  \
# ...

# %%
import matplotlib.pyplot as plt #using matplotlib and np to plot histogram
import numpy as np
plt.style.use('ggplot')

#creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
binwidth=500
ax.hist(Geo['judgment_amt'], bins=np.arange(min(Geo['judgment_amt']), max(Geo['judgment_amt']) + binwidth, binwidth), color='xkcd:faded blue')

#adding labels and title
plt.xlabel("Judgment Amounts")
plt.ylabel("Number of Judgments")
plt.title('Distribution of Judgment Amounts Sentenced in Eviction Cases')

#showing plot
plt.show()

# %%
#from census import Census
#from us import states
#import os
#tx_tract = geopandas.read_file("https://www2.census.gov/geo/tiger/TIGER2020/TRACT/tl_2020_48_tract.zip")
#tx_tract = tx_tract.to_crs(epsg = 32617)

# %%
Housing=pd.read_csv('Cleaner Housing Characteristics.csv').transpose() #reading in Housing Characteristcs

# %%
#transpose the census tracts
#take out "Dallas County" and put it under name
#str plit by !!
#

#renaming columns
Housing.columns = Housing[0:1].values.tolist()

#dropping column Label Grouping
Housing_new = Housing.drop(index=['Label (Grouping)'])

Housing_new.head(10)

#creating for loop name and value and adding a new value from the split on !!
name = []
value = []
#str plit by !!
for i in Housing_new.index:
    name.append(i.split('!!')[0])
    value.append(i.split('!!')[2])


#moving name to front
Housing_new.insert(loc=0, column= 'NAME', value=name)

#moving value to second column
Housing_new.insert(loc=1, column= 'RESPONSE_TYPE', value = value)
# Out:
#                                                                                         NAME  \
# Census Tract 56; Dallas County; Texas!!Total po...     Census Tract 56; Dallas County; Texas
# Census Tract 56; Dallas County; Texas!!Total po...     Census Tract 56; Dallas County; Texas
# Census Tract 56; Dallas County; Texas!!Total po...     Census Tract 56; Dallas County; Texas
# Census Tract 56; Dallas County; Texas!!Total po...     Census Tract 56; Dallas County; Texas
# Census Tract 80; Dallas County; Texas!!Total po...     Census Tract 80; Dallas County; Texas
# Census Tract 80; Dallas County; Texas!!Total po...     Census Tract 80; Dallas County; Texas
# Census Tract 80; Dallas County; Texas!!Total po...     Census Tract 80; Dallas County; Texas
# Census Tract 80; Dallas County; Texas!!Total po...     Census Tract 80; Dallas County; Texas
# Census Tract 93.04; Dallas County; Texas!!Total...  Census Tract 93.04; Dallas County; Texas
# ...

# %%
#housing_col = Housing.columns.values.tolist()  #
#Housing_new[['name', 'value', housing_col]] #moving new columns of name and value to the beginning of the of the data frame

# %%
#Housing_new.to_csv('House Cleaned.csv',index=False)  #saving cleaned dataframe
Households.head(10)
# Out:
#                  GEO_ID                                     NAME  \
# 0             Geography                     Geographic Area Name
# 1  1400000US48113000100     Census Tract 1, Dallas County, Texas
# 2  1400000US48113000201  Census Tract 2.01, Dallas County, Texas
# 3  1400000US48113000202  Census Tract 2.02, Dallas County, Texas
# 4  1400000US48113000300     Census Tract 3, Dallas County, Texas
# 5  1400000US48113000401  Census Tract 4.01, Dallas County, Texas
# 6  1400000US48113000405  Census Tract 4.05, Dallas County, Texas
# 7  1400000US48113000407  Census Tract 4.07, Dallas County, Texas
# 8  1400000US48113000408  Census Tract 4.08, Dallas County, Texas
# 9  1400000US48113000409  Census Tract 4.09, Dallas County, Texas
#
#                                   S1101_C01_001E  \
# 0  Estimate!!Total!!HOUSEHOLDS!!Total households
# 1                                           1717
# 2                                           1186
# 3                                           1733
# ...

# %%
Households=pd.read_csv('Households.csv')
#renaming columns
Households.columns = Households[0:1].values.tolist()

#dropping first row
Householdsnew=Households.drop([0])

#dropping columns with the column label name "Annotation" using a filter command
Householdsnew = Householdsnew[Householdsnew.columns.drop(list(Householdsnew.filter(regex='Annotation')))]

Householdsnew.to_csv('Householdsnew Cleaned.csv',index=False)
#Householdsnew.head(10)

# %%
School=pd.read_csv('Schoolenrollment.csv')


#renaming columns of dataframe to first row values
School.columns = School[0:1].values.tolist()

#dropping first row
Schoolnew=School.drop([0])



Schoolnew = Schoolnew[Schoolnew.columns.drop(list(Schoolnew.filter(regex='Annotation')))]

Schoolnew.head(10)

Schoolnew.to_csv('Schoolnew Cleaned.csv',index=False)

# %%
ev_cases= pd.read_csv('NTEP_eviction_cases.csv')
outlier=pd.read_csv('nonzero_jud_geo_no_bus_outliers.csv')
# Out:
# /tmp/ipykernel_3033189/1374693145.py:1: DtypeWarning: Columns (4,5,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev_cases= pd.read_csv('NTEP_eviction_cases.csv')

# %%
outlier.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0 case_number   file_date judgment_date.x  \
# 0            86          87    2102530G  12/13/2021       3/21/2022
# 1           100         101    2102681D  12/22/2021        3/9/2022
# 2           221         229    2200229D   1/21/2022        4/5/2022
# 3           465         503    2200340K   2/22/2022       3/10/2022
# 4           549         587    2200361K    3/1/2022       3/11/2022
# 5           611         649    2200377K    3/7/2022       3/22/2022
# 6           699         737    2200400L    3/9/2022        4/5/2022
# 7           787         825    2200423E   3/11/2022       3/28/2022
# 8           793         831    2200425D   2/11/2022       3/30/2022
# 9           794         832    2200425D   2/11/2022       4/13/2022
#
#   judgment_signed  judgment_amt  total_paid       court  filed_date  ...  \
# 0       3/21/2022       9864.48       141.0  Court  4-1  12/13/2021  ...
# ...

# %%
import matplotlib.pyplot as plt #using matplotlib and np to plot histogram
import numpy as np
plt.style.use('ggplot')

#creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
binwidth=500
ax.hist(outlier['judgment_amt'], bins=np.arange(min(outlier['judgment_amt']), max(outlier['judgment_amt']) + binwidth, binwidth), color='xkcd:faded blue')

#adding labels and title
plt.xlabel("Judgment Amounts")
plt.ylabel("Number of Judgments")
plt.title('Distribution of Judgment Amounts Sentenced in Eviction Cases')


#showing plot
plt.show()

# %%
outlier_judgment=outlier.groupby('judgment_amt')

plt.style.use('ggplot')
#creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
binwidth=500
ax.hist(outlier['judgment_amt'], bins=np.arange(min(outlier['judgment_amt']), max(outlier['judgment_amt']) + binwidth, binwidth), color='xkcd:faded blue')

#adding labels and title
plt.xlabel("Judgment Amounts")
plt.ylabel("Number of Judgments")
plt.title('Distribution of Judgment Amounts Sentenced in Eviction Cases')


#showing plot
plt.show()

# %%
nonzb= pd.read_csv('nonzero_jud_geo_no_bus.csv')

# %%
nonzb.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 case_number   file_date judgment_date.x  \
# 0             0           1    2100568E   8/11/2021       3/14/2022
# 1             3           4    2100818E  10/22/2021       5/16/2022
# 2             4           5    2100825E  10/28/2021       3/14/2022
# 3            11          12    2100854E   11/8/2021       3/18/2022
# 4            19          20    2100925K  10/25/2021       3/10/2022
#
#   judgment_signed  judgment_amt total_paid       court  filed_date  ...  \
# 0       3/14/2022       4378.00        141  Court  2-2   8/11/2021  ...
# 1             NaN       5637.26        221  Court  2-2  10/22/2021  ...
# 2       3/14/2022       4789.09        141  Court  2-2  10/28/2021  ...
# 3       3/18/2022       3557.70        141  Court  2-2   11/8/2021  ...
# 4       3/10/2022       4058.29        141  Court  1-2  10/25/2021  ...
#
#   judgment_date.y amount_filed            NAME_2020   GEOID_2020  \
# ...

# %%
Rec.head()
# Out:
#   case_number       court filed_date appearance_date appearance_time  \
# 0    2202635A  Court  3-1 2022-05-06      2022-05-23        10:00:00
# 1    2202632A  Court  3-1 2022-05-06      2022-05-23        10:00:00
# 2    2202634A  Court  3-1 2022-05-06      2022-05-23        10:00:00
# 3    2202633A  Court  3-1 2022-05-06      2022-05-23        10:00:00
# 4    2251510P  Court  5-2 2022-05-06      2022-05-23        09:00:00
#
#   non_payment_of_rent                    plaintiff_name  \
# 0                   Y  9701 WEST FERRIS BRANCH BLVD LLC
# 1                   Y  9701 WEST FERRIS BRANCH BLVD LLC
# 2                   Y  9701 WEST FERRIS BRANCH BLVD LLC
# 3                   Y  9701 WEST FERRIS BRANCH BLVD LLC
# 4                   Y                    CAMDEN BELMONT
#
#                   pl_address pl_city pl_state  ...  amount_filed monthly_rent  \
# 0  9701 W FERRIS BRANCH BLVD  DALLAS       TX  ...       1349.00       1349.0
# ...

# %%
Records=Rec.groupby('plaintiff_name').count()

Rec[Rec['case_number']=='2202635A']
# Out:
#   case_number       court filed_date appearance_date appearance_time  \
# 0    2202635A  Court  3-1 2022-05-06      2022-05-23        10:00:00
#
#   non_payment_of_rent                    plaintiff_name  \
# 0                   Y  9701 WEST FERRIS BRANCH BLVD LLC
#
#                   pl_address pl_city pl_state  ...  amount_filed monthly_rent  \
# 0  9701 W FERRIS BRANCH BLVD  DALLAS       TX  ...        1349.0       1349.0
#
#   receiving_subsidy           NAME_2020   GEOID_2020           NAME_2010  \
# 0                 N  Census Tract 78.34  48113007834  Census Tract 78.11
#
#     GEOID_2010       lon       lat    zip
# 0  48113007811 -96.72552  32.90354  75243
#
# [1 rows x 29 columns]

# %%
import pandas as pd
import numpy as np
Geonobus= pd.read_csv('jud_geo_no_bus_ad_filter.csv')
Geonobus.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 case_number   file_date judgment_date.x  \
# 0             0           1    2100568E   8/11/2021       3/14/2022
# 1             1           2    2100785E  10/13/2021       3/18/2022
# 2             2           3    2100804K   10/8/2021       4/14/2022
# 3             3           4    2100818E  10/22/2021       5/16/2022
# 4             4           5    2100825E  10/28/2021       3/14/2022
#
#   judgment_signed  judgment_amt total_paid       court  filed_date  ...  \
# 0       3/14/2022       4378.00        141  Court  2-2   8/11/2021  ...
# 1       3/18/2022          0.00        141  Court  2-2  10/13/2021  ...
# 2       4/14/2022          0.00        141  Court  1-2   10/8/2021  ...
# 3             NaN       5637.26        221  Court  2-2  10/22/2021  ...
# 4       3/14/2022       4789.09        141  Court  2-2  10/28/2021  ...
#
#              NAME_2020   GEOID_2020            NAME_2010   GEOID_2010  \
# ...

# %%
Geonobus.columns

#Schoolnew = Schoolnew[Schoolnew.columns.drop(list(Schoolnew.filter(regex='Annotation')))]
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'case_number', 'file_date',
#        'judgment_date.x', 'judgment_signed', 'judgment_amt', 'total_paid',
#        'court', 'filed_date', 'pl_address', 'pl_city', 'pl_state', 'pl_zip',
#        'defendant_name', 'df_address', 'df_city', 'df_state', 'df_zip',
#        'judgment_date.y', 'amount_filed', 'NAME_2020', 'GEOID_2020',
#        'NAME_2010', 'GEOID_2010', 'lon', 'lat', 'zip', 'def_business'],
#       dtype='object')

# %%
import pandas as pd
med=pd.read_csv('dallas_median_purerent.csv')

# %%
med.head()
# Out:
#                  GEO_ID                                     NAME  \
# 0             Geography                     Geographic Area Name
# 1  1400000US48113000100     Census Tract 1, Dallas County, Texas
# 2  1400000US48113000201  Census Tract 2.01, Dallas County, Texas
# 3  1400000US48113000202  Census Tract 2.02, Dallas County, Texas
# 4  1400000US48113000300     Census Tract 3, Dallas County, Texas
#
#                       B25058_001E  \
# 0  Estimate!!Median contract rent
# 1                            1278
# 2                            1575
# 3                            1118
# 4                            1667
#
#                                    B25058_001EA  \
# 0  Annotation of Estimate!!Median contract rent
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                              B25058_001M  \
# ...

# %%
med.columns= med[0:1].values.tolist()

# %%
med.head()
# Out:
#               Geography                     Geographic Area Name  \
# 0             Geography                     Geographic Area Name
# 1  1400000US48113000100     Census Tract 1, Dallas County, Texas
# 2  1400000US48113000201  Census Tract 2.01, Dallas County, Texas
# 3  1400000US48113000202  Census Tract 2.02, Dallas County, Texas
# 4  1400000US48113000300     Census Tract 3, Dallas County, Texas
#
#    Estimate!!Median contract rent  \
# 0  Estimate!!Median contract rent
# 1                            1278
# 2                            1575
# 3                            1118
# 4                            1667
#
#    Annotation of Estimate!!Median contract rent  \
# 0  Annotation of Estimate!!Median contract rent
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Margin of Error!!Median contract rent  \
# ...

# %%
mednew= med.drop([0])

# %%
mednew.head()
# Out:
#               Geography                     Geographic Area Name  \
# 1  1400000US48113000100     Census Tract 1, Dallas County, Texas
# 2  1400000US48113000201  Census Tract 2.01, Dallas County, Texas
# 3  1400000US48113000202  Census Tract 2.02, Dallas County, Texas
# 4  1400000US48113000300     Census Tract 3, Dallas County, Texas
# 5  1400000US48113000401  Census Tract 4.01, Dallas County, Texas
#
#   Estimate!!Median contract rent Annotation of Estimate!!Median contract rent  \
# 1                           1278                                          NaN
# 2                           1575                                          NaN
# 3                           1118                                          NaN
# 4                           1667                                          NaN
# 5                           1335                                          NaN
#
#   Margin of Error!!Median contract rent  \
# 1                                   118
# ...

# %%
mednew= mednew[mednew.columns.drop(list(mednew.filter(regex='Annotation')))]

# %%
mednew.head()
# Out:
#               Geography                     Geographic Area Name  \
# 1  1400000US48113000100     Census Tract 1, Dallas County, Texas
# 2  1400000US48113000201  Census Tract 2.01, Dallas County, Texas
# 3  1400000US48113000202  Census Tract 2.02, Dallas County, Texas
# 4  1400000US48113000300     Census Tract 3, Dallas County, Texas
# 5  1400000US48113000401  Census Tract 4.01, Dallas County, Texas
#
#   Estimate!!Median contract rent Margin of Error!!Median contract rent NaN
# 1                           1278                                   118 NaN
# 2                           1575                                   764 NaN
# 3                           1118                                   451 NaN
# 4                           1667                                   141 NaN
# 5                           1335                                    49 NaN

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#path_to_data = geopandas.datasets.get_path("nybb")
gdf = gpd.read_file('dallas_median_purerent.csv')
gdf.columns= gdf[0:1].values.tolist()
gdfnew= gdf.drop([0])
gdfnew= gdfnew[gdfnew.columns.drop(list(gdfnew.filter(regex='Annotation')))]

# %%
#value= gdfnew.Geography.values.tolist()
#gdfnew[gdfnew.sort_values(by=value)]
type(gdfnew.Geography.values)
# Out:
# numpy.ndarray

# %%
import pandas as pd
import geopandas as gpd


df = gpd.read_file("tl_2022_48_tract.shp")

df.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      48      187  210707  48187210707  2107.07  Census Tract 2107.07  G5020
# 1      48      187  210709  48187210709  2107.09  Census Tract 2107.09  G5020
# 2      48      187  210711  48187210711  2107.11  Census Tract 2107.11  G5020
# 3      48      085  031673  48085031673   316.73   Census Tract 316.73  G5020
# 4      48      439  113809  48439113809  1138.09  Census Tract 1138.09  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  7684752   16960  +29.5796294  -098.2944795
# 1        S  4399576       0  +29.5922662  -098.2812989
# 2        S  3704218       0  +29.5990695  -098.2674716
# 3        S   688650       0  +33.0629491  -096.7936306
# 4        S  2475720       0  +32.8654907  -097.2526443
#
#                                             geometry
# 0  POLYGON ((-98.31206 29.59085, -98.31201 29.591...
# 1  POLYGON ((-98.29620 29.60001, -98.29618 29.600...
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME', 'NAMELSAD', 'MTFCC',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df.boundary.plot()
# Out:
# <Axes: >

# %%
df.sort_values(by=['GEOID'])
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  \
# 2397      48      001  950100  48001950100     9501     Census Tract 9501
# 6723      48      001  950401  48001950401  9504.01  Census Tract 9504.01
# 6725      48      001  950402  48001950402  9504.02  Census Tract 9504.02
# 2396      48      001  950500  48001950500     9505     Census Tract 9505
# 2399      48      001  950600  48001950600     9506     Census Tract 9506
# ...      ...      ...     ...          ...      ...                   ...
# 1988      48      505  950402  48505950402  9504.02  Census Tract 9504.02
# 6142      48      507  950100  48507950100     9501     Census Tract 9501
# 6145      48      507  950200  48507950200     9502     Census Tract 9502
# 6143      48      507  950301  48507950301  9503.01  Census Tract 9503.01
# 6144      48      507  950302  48507950302  9503.02  Census Tract 9503.02
#
#       MTFCC FUNCSTAT       ALAND     AWATER     INTPTLAT      INTPTLON  \
# ...

# %%
df.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME', 'NAMELSAD', 'MTFCC',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
Resi=pd.read_excel('ResidentialJudgements.xlsx')

# %%
Resid.head()
# Out:
#    case_number   defendant_name                          Defendant Address  \
# 0     2100568E    WEST VALENSIA  11760 FERGUSON RD 1013, DALLAS, TX, 75228
# 10    2100846K    GIPSON SHEREE   3783 LEGENDARY LN 203, DALLAS, TX, 75224
# 12    2100868K  SLATTON CYNTHIA      1312 EAGLE ROCK 97, DALLAS, TX, 75253
# 13    2100872K    FARMER SHEILA     420 W LAWSON RD 110, DALLAS, TX, 75253
# 15    2100889K     LAWSON JARIA  3220 PERSIMMON RD 1026, DALLAS, TX, 75241
#
#                 df_address df_city df_state   df_zip filed_date      court  \
# 0   11760 FERGUSON RD 1013  DALLAS       TX  75228.0 2021-08-11  Court 2-2
# 10   3783 LEGENDARY LN 203  DALLAS       TX  75224.0 2021-10-12  Court 1-2
# 12      1312 EAGLE ROCK 97  DALLAS       TX  75253.0 2021-10-13  Court 1-2
# 13     420 W LAWSON RD 110  DALLAS       TX  75253.0 2021-10-15  Court 1-2
# 15  3220 PERSIMMON RD 1026  DALLAS       TX  75241.0 2021-10-19  Court 1-2
#
# ...

# %%
Resid= Resi[Resi['df_city']=='DALLAS']

# %%
income=pd.read_csv('ACSST5Y2020 Income.csv')

# %%
# Out:
#                        Label (Grouping) Occupied housing units  \
# 0  Census Tract 1, Dallas County, Texas                    NaN
# 1                Occupied housing units                    NaN
# 2                              Estimate                  1,797
# 3        Percent occupied housing units                    NaN
# 4                              Estimate                  1,797
#
#    Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS)!!Less than $5,000  \
# 0                                                NaN
# ...

# %%
inc=pd.read_csv('dallas_income.csv')

# %%
inc.head()
# Out:
#                                      Tract  Total Housing Units  \
# 0     Census Tract 1, Dallas County, Texas                 1797
# 1  Census Tract 2.01, Dallas County, Texas                 1278
# 2  Census Tract 2.02, Dallas County, Texas                 1850
# 3     Census Tract 3, Dallas County, Texas                 2111
# 4  Census Tract 4.01, Dallas County, Texas                 1781
#
#    Owner Housing Units  Renter Housing Units  Total Median Income  \
# 0                  994                   803               127625
# 1                 1030                   248               156000
# 2                  930                   920               123571
# 3                 1035                  1076                86741
# 4                  250                  1531                52347
#
#    Owner Median Income  Renter Median Outcome  Validation
# 0               210638                  78860           0
# 1               183854                  76250           0
# ...

# %%
inc1=inc.drop(columns= 'Validation')

# %%
inc1.head()
# Out:
#                                      Tract  Total Housing Units  \
# 0     Census Tract 1, Dallas County, Texas                 1797
# 1  Census Tract 2.01, Dallas County, Texas                 1278
# 2  Census Tract 2.02, Dallas County, Texas                 1850
# 3     Census Tract 3, Dallas County, Texas                 2111
# 4  Census Tract 4.01, Dallas County, Texas                 1781
#
#    Owner Housing Units  Renter Housing Units  Total Median Income  \
# 0                  994                   803               127625
# 1                 1030                   248               156000
# 2                  930                   920               123571
# 3                 1035                  1076                86741
# 4                  250                  1531                52347
#
#    Owner Median Income  Renter Median Outcome
# 0               210638                  78860
# 1               183854                  76250
# ...

# %%
inc1["Renter Median Outcome"].rename
inc1.rename(columns={"Renter Median Outcome": "Renter Median Income"})
# Out:
#                                        Tract  Total Housing Units  \
# 0       Census Tract 1, Dallas County, Texas                 1797
# 1    Census Tract 2.01, Dallas County, Texas                 1278
# 2    Census Tract 2.02, Dallas County, Texas                 1850
# 3       Census Tract 3, Dallas County, Texas                 2111
# 4    Census Tract 4.01, Dallas County, Texas                 1781
# ..                                       ...                  ...
# 640   Census Tract 211, Dallas County, Texas                 1793
# 641   Census Tract 212, Dallas County, Texas                 1486
# 642  Census Tract 9800, Dallas County, Texas                    0
# 643  Census Tract 9801, Dallas County, Texas                    0
# 644  Census Tract 9802, Dallas County, Texas                  807
#
#      Owner Housing Units  Renter Housing Units  Total Median Income  \
# 0                    994                   803               127625
# ...

# %%
Geonobus.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 case_number   file_date judgment_date.x  \
# 0             0           1    2100568E   8/11/2021       3/14/2022
# 1             1           2    2100785E  10/13/2021       3/18/2022
# 2             2           3    2100804K   10/8/2021       4/14/2022
# 3             3           4    2100818E  10/22/2021       5/16/2022
# 4             4           5    2100825E  10/28/2021       3/14/2022
#
#   judgment_signed  judgment_amt total_paid       court  filed_date  ...  \
# 0       3/14/2022       4378.00        141  Court  2-2   8/11/2021  ...
# 1       3/18/2022          0.00        141  Court  2-2  10/13/2021  ...
# 2       4/14/2022          0.00        141  Court  1-2   10/8/2021  ...
# 3             NaN       5637.26        221  Court  2-2  10/22/2021  ...
# 4       3/14/2022       4789.09        141  Court  2-2  10/28/2021  ...
#
#              NAME_2020   GEOID_2020            NAME_2010   GEOID_2010  \
# ...

# %%
#compare number of months back rent to the percent rent of income
#brmonths= Geonobus['judgment_amt']/gdfnew["Estimate!!Median contract rent"]
#merged = pd.merge(
df=pd.read_csv('tx_tract_jud_geo_median_rent_income.csv')
df.head()
# Out:
#    Unnamed: 0  STATEFP  COUNTYFP  TRACTCE         GEOID  NAME_x  \
# 0           0       48       113    15900  4.811302e+10  159.00
# 1           1       48       113    12604  4.811301e+10  126.04
# 2           2       48       113    13010  4.811301e+10  130.10
# 3           3       48       113    13622  4.811301e+10  136.22
# 4           4       48       113    13621  4.811301e+10  136.21
#
#               NAMELSAD  MTFCC FUNCSTAT    ALAND  ...  Median_Months_Judgment  \
# 0     Census Tract 159  G5020        S  5703840  ...                3.042328
# 1  Census Tract 126.04  G5020        S  2510513  ...                2.986111
# 2  Census Tract 130.10  G5020        S  1404466  ...                3.308445
# 3  Census Tract 136.22  G5020        S  1249629  ...                1.732320
# 4  Census Tract 136.21  G5020        S   910824  ...                1.582593
#
#                                        Tract  Total Housing Units  \
# ...

# %%
#compare number of months back rent to the percent rent of income


import matplotlib.pyplot as plt #using matplotlib and np to plot histogram
import numpy as np
plt.style.use('ggplot')

plt.scatter(df['Median_Months_Judgment'], df['pct_med_rent_income'])

#adding labels and title
plt.xlabel("Median Judgment Months")
plt.ylabel("Percent Rent of Income")
plt.title('Percent rent of Income per Median Judgment Months')

#showing plot
plt.show()

# %%
import matplotlib.pyplot as plt #using matplotlib and np to plot histogram
import numpy as np
plt.style.use('ggplot')

#creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
binwidth=3
#ax.hist(Geo['judgment_amt'], bins=np.arange(min(Geo['judgment_amt']), max(Geo['judgment_amt']) + binwidth, binwidth), color='xkcd:faded blue')
ax.hist(df['pct_med_rent_income'],bins=np.arange(min(df['pct_med_rent_income']), max(df['pct_med_rent_income']) + binwidth, binwidth), color='xkcd:faded blue')
#ax.hist(df['Median_Months_Judgment'], df['pct_med_rent_income'])

#adding labels and title
plt.xlabel("Percent Rent of Income")
plt.ylabel("Number of People")
plt.title('Distribution of Percent Rent of Income')

#showing plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       7 binwidth=3
#       8 #ax.hist(Geo['judgment_amt'], bins=np.arange(min(Geo['judgment_amt']), max(Geo['judgment_amt']) + binwidth, binwidth), color='xkcd:faded blue')
# ----> 9 ax.hist(df['pct_med_rent_income'],bins=np.arange(min(df['pct_med_rent_income']), max(df['pct_med_rent_income']) + binwidth, binwidth), color='xkcd:faded blue')
#      10 #ax.hist(df['Median_Months_Judgment'], df['pct_med_rent_income'])
#      11
#      12 #adding labels and title
#      13 plt.xlabel("Percent Rent of Income")
#
# NameError: name 'df' is not defined

# %%
plt.style.use('ggplot')
#creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
binwidth=1
#ax.hist(Geo['judgment_amt'], bins=np.arange(min(Geo['judgment_amt']), max(Geo['judgment_amt']) + binwidth, binwidth), color='xkcd:faded blue')
ax.hist(df['Median_Months_Judgment'],bins=np.arange(min(df['Median_Months_Judgment']), max(df['Median_Months_Judgment']) + binwidth, binwidth), color='xkcd:faded blue')
#ax.hist(df['Median_Months_Judgment'], df['pct_med_rent_income'])

#adding labels and title
plt.xlabel("Median Judgment Months")
plt.ylabel("Number of People")
plt.title('Distribution of Median Judgment Months')

#showing plot
plt.show()

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 19.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.boxplot(df, x= df['Median_Months_Judgment'], y=df['pct_med_rent_income'])
# Out:
# <Axes: xlabel='Median_Months_Judgment', ylabel='pct_med_rent_income'>

# %%
#pct rent of income/median judgment month
# Out:
# 8.333333333333334

# %% [markdown]
# df1.rename(columns={'Renter Median Outcome':'Renter Median Income'})

# %%
df1= df.rename(columns={'Renter Median Outcome':'Renter Median Income'})

# %%
df1=df1.drop(columns='Validation')

# %%
# Extract yr-mo
def def_names(df):
    df['def_business'] = 0
        
    # Sort out defendent names containing a key word
    key_words = [' INC', ' LLC', 'SHOP', ' LLP', 'RESTAURANT', 'PARTNER', 'CORP']
    for key in key_words:
        df.loc[df['defendant_name'].str.contains(key), 'def_business'] = 1
    
    return(df)
    evict_hist_def_names = def_names(evict_hist)
evict_hist_no_bus = evict_hist_def_names[evict_hist_def_names['def_business'] == 0]
len(evict_hist_no_bus)
evict_yr_mo = []
evict_mo = []
for i in evict_hist_no_bus['filed_date'].astype(str):
    if len(i.split('-')) > 2:
        evict_yr_mo.append(i.split('-')[0] + '-' + i.split('-')[1])
        evict_mo.append(i.split('-')[1])
    else:
        evict_yr_mo.append(i.split('-')[0])
        evict_mo.append('Na')
        evict_hist_yr_mo_group = evict_hist_no_bus.groupby('yr_mo').nunique()
evict_hist_yr_mo_group = evict_hist_yr_mo_group.drop(index=['2011-11','NaT'])
evict_hist_yr_mo_group['yr_mo_col'] = evict_hist_yr_mo_group.index
evict_hist_yr_mo_group.head(3)
evict_hist_yr_mo_group
# Out:
# Index(['Unnamed: 0', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME_x',
#        'NAMELSAD', 'MTFCC', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT',
#        'INTPTLON', 'geometry', 'GEOID_2020', 'Num_Evict',
#        'Median_Judgment_Amt', 'NAME_y', 'Estimate_Rent',
#        'Median_Months_Judgment', 'Tract', 'Total Housing Units',
#        'Owner Housing Units', 'Renter Housing Units', 'Total Median Income',
#        'Owner Median Income', 'Renter Median Income', 'pct_med_rent_income'],
#       dtype='object')

# %%
# Zooming into moratorium to graph
mora_color = 'red'
ax.axvline('2020-08', color=mora_color, alpha=0.7)
ax.axvline('2021-09', color=mora_color, alpha=0.7)
ax.annotate('------------Eviction Moratorium------------', xy =('2021-09', text_y-1000), ha='right', color=mora_color)

# Add regression plots
pol_order=1
lin_plot = sns.regplot(x ='yr_mo_col_ord', y ='case_number', order=1, color=pre_col,
                       data = evict_hist_yr_mo_group[evict_hist_yr_mo_group['covid_status']=='Pre-Covid'], ax=ax);

lin_plot = sns.regplot(x ='yr_mo_col_ord', y ='case_number', order=1, color=post_col,
                       data = evict_hist_yr_mo_group[evict_hist_yr_mo_group['covid_status']=='Covid and Post-Covid'], ax=ax).set(title='Number of Evictions by Month and Year', 
                                           ylabel='Number of Evictions', xlabel='Year-Month');
